# %%
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install sastrawi
# !pip install emoji
# !pip install PySastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.0 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.3/356.3 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for emoji: filename=emoji-2.5.1-py2.py3-none-any.whl size=351210 sha256=d6133e6f6477a09aec0ae3be49dd7acfa45fdcc386fbf48fdd8b810f4ef707a8
#   Stored in directory: /root/.cache/pip/wheels/51/92/44/e2ef13f803aa08711819357e6de0c5fe67b874671141413565
# Successfully built emoji
# ...

# %%
import os
import pandas as pd
import tweepy
import re
import string
from textblob import TextBlob
import preprocessor as p
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import datetime
from datetime import timedelta
import numpy as np
import emoji
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
#read data
import pandas as pd
def load_data():
  data - pd.read_excel('/content/siaplexicon.xlsx')
  return data

# %%
TWEET_DATA = pd.read_excel("/content/siaplexicon.xlsx")
TWEET_DATA.head(100)
# Out:
#                                              komentar
# 0   ['gara', 'vaksin', 'gabisa', 'mana', 'anjjjjg'...
# 1   ['mantab', 'mbak', 'kluarga', 'vaksin', 'vaksi...
# 2                                  ['alah', 'muakkk']
# 3                        ['vaksin', 'langgar', 'ham']
# 4                            ['vaksin', '', 'sholat']
# ..                                                ...
# 95                      ['paksa', 'vaksin', 'paraah']
# 96  ['ah', 'paksa', 'vaksin', 'bosentar', 'rumit',...
# 97                                          ['kacaw']
# 98                                   ['sy', 'vaksin']
# 99  ['paksin', 'didak', 'wajib', 'wajib', 'ganti',...
#
# [100 rows x 1 columns]

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import googletrans
from googletrans import Translator

# %%
df = pd.read_excel('/content/siaplexicon.xlsx')
df.head(10)
# Out:
#                                             komentar
# 0  ['gara', 'vaksin', 'gabisa', 'mana', 'anjjjjg'...
# 1  ['mantab', 'mbak', 'kluarga', 'vaksin', 'vaksi...
# 2                                 ['alah', 'muakkk']
# 3                       ['vaksin', 'langgar', 'ham']
# 4                           ['vaksin', '', 'sholat']
# 5  ['vaksin', 'fix', 'selamat', 'vaksin', 'copit'...
# 6  ['bisnis', 'vaksin', 'dunia', 'indonesia', 'pe...
# 7  ['vaksin', 'vaksin', 'hak', 'orang', 'harga', ...
# 8  ['kemaren', 'habis', 'vaksin', 'dosis', 'jujur...
# 9  ['orang', 'nggk', 'vaksin', 'nggk', 'sekolah',...

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#lexiconbased
# !pip install VaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
df = pd.read_excel('/content/siaplexicon.xlsx')
df.head()
# Out:
#                                             komentar
# 0  ['gara', 'vaksin', 'gabisa', 'mana', 'anjjjjg'...
# 1  ['mantab', 'mbak', 'kluarga', 'vaksin', 'vaksi...
# 2                                 ['alah', 'muakkk']
# 3                       ['vaksin', 'langgar', 'ham']
# 4                           ['vaksin', '', 'sholat']

# %%
scores = [analyser.polarity_scores(x) for x in df['komentar']]
print(scores)
df['Compound_Scores'] = [x['compound'] for x in scores]
# Out:
# [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.952, 'pos': 0.048, 'compound': 0.0516}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.0516}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'com
# ...

# %%
TWEET_DATA.to_excel("/content/komentarkompasmaulexicon.xlsx")

# %%
df.nsmallest(10, ['Compound_Scores']) #melihat score terkecil
# Out:
#                                                 komentar  Compound_Scores
# 18165  ['bbc', 'presenter', 'died', 'after', 'astraze...          -0.9845
# 3115   ['morvin', 'black', 'logika', 'ambil', 'salah'...          -0.9678
# 16677  ['dongen', 'indonesia', 'baru', 'paksin', 'tin...          -0.8720
# 8478   ['zzz', 'coba', 'resah', 'pandemi', 'kunjung',...          -0.8316
# 14207  ['marlina', 'the', 'mau', 'menang', 'egois', '...          -0.8316
# 16913  ['saudara', 'hasil', 'mri', 'udah', 'tahu', 'k...          -0.8176
# 3932   ['dickipoetra', 'regil', 'vaksin', 'coy', 'pak...          -0.8020
# 5339                                     ['fuck', 'sin']          -0.7964
# 6028   ['knapa', 'negative', 'netizen', 'knapa', 'doa...          -0.7906
# 12534  ['pnyakit', 'jantung', 'pmbuluh', 'darahpenggu...          -0.7906

# %%
df.nlargest(10, ['Compound_Scores'])
# Out:
#                                                 komentar  Compound_Scores
# 4190   ['faried', 'drian', 'faried', 'adrian', 'lu', ...           0.9674
# 18385  ['happy', 'keluarga', 'minum', 'vitamin', 'sem...           0.9623
# 10604  ['irwaniwekz', 'iya', 'coba', 'bener', 'susah'...           0.9153
# 8389   ['dedi', 'irawan', 'contoh', 'salah', 'beban',...           0.9001
# 2302   ['cacing', 'hak', 'wajib', 'hak', 'dpt', 'kerj...           0.8910
# 2416   ['vaksin', 'free', 'aneh', 'obat', 'sakit', 'k...           0.8720
# 5707   ['asnawitellor', 'ur', 'welcome', 'and', 'hope...           0.8720
# 17624  ['sofian', 'bollysmack', 'nurut', 'tulis', 'ti...           0.8720
# 14043  ['government', 'is', 'really', 'smart', 'no', ...           0.8441
# 17495  ['cheryl', 'gavin', 'hajar', 'pake', 'makan', ...           0.8402

# %%
df.loc[df['Compound_Scores'] < 0, 'Sentiments'] = 'Negative'
df.loc[df['Compound_Scores'] > 0, 'Sentiments'] = 'Positive'
df.head()
# Out:
#                                             komentar  Compound_Scores  \
# 0  ['gara', 'vaksin', 'gabisa', 'mana', 'anjjjjg'...              0.0
# 1  ['mantab', 'mbak', 'kluarga', 'vaksin', 'vaksi...              0.0
# 2                                 ['alah', 'muakkk']              0.0
# 3                       ['vaksin', 'langgar', 'ham']              0.0
# 4                           ['vaksin', '', 'sholat']              0.0
#
#   Sentiments
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.to_csv('kompastvlexicon.csv', encoding= 'utf8', index=False)

# %%
df.to_excel('lexicondone.xlsx')

# %% [markdown]
# # New Section
